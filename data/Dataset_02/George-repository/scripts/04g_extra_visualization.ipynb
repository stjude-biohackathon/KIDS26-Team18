# %%
from pathlib import Path
import os
import sys

# Project root
ROOT = Path(
    "/research/rgs01/home/clusterHome/jqu/activities/learning/"
    "BioHackathon/BioHackathon-2026/"
    "Dataset_02_CosMx_revised/Dataset_02_CosMx_revised"
)

# Change notebook working directory to project root
os.chdir(ROOT)

# Make project modules importable
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("Working directory:", Path.cwd())
print("Python executable:", sys.executable)
# Out:
# Working directory: /research/rgs01/home/clusterHome/jqu/activities/learning/BioHackathon/BioHackathon-2026/Dataset_02_CosMx_revised/Dataset_02_CosMx_revised
# Python executable: /home/jqu/.conda/envs/spatialdata/bin/python

# %%
import matplotlib.pyplot as plt
import scanpy as sc

from src.plotting import spatial_scatter
from config.markers import MARKER_PANEL
