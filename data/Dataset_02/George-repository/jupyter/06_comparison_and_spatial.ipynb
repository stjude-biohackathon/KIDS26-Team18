# %% [markdown]
# # 06 — Compare Approach I, Approach II, reference annotation, and SpatialData
#
# Runs the production comparison and transcript/segmentation overlay scripts, then exposes the key tables interactively. `final_CT` is treated as a **reference annotation**, not absolute ground truth.

# %%
from pathlib import Path
import sys, os

# Notebook lives in PROJECT_ROOT/jupyter/.
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "jupyter" else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT:", PROJECT_ROOT)
print("Python:", sys.executable)
assert (PROJECT_ROOT / "scripts").exists(), "Run this notebook from PROJECT_ROOT/jupyter or PROJECT_ROOT."
# Out:
# PROJECT_ROOT: /research/rgs01/home/clusterHome/jqu/activities/learning/BioHackathon/BioHackathon-2026/Dataset_02_CosMx_revised/Dataset_02_CosMx_revised
# Python: /home/jqu/.conda/envs/spatialdata/bin/python

# %%
# %run ../scripts/04e_compare_approaches.py

# %% [markdown]
# ## Contingency / concordance tables

# %%
import pandas as pd
from IPython.display import display
TAB=PROJECT_ROOT/"results/FOV46/tables"
for name in ["approach_i_vs_ii_counts.csv","approach_i_vs_ii_row_fraction.csv","reference_vs_approach_i_counts.csv","reference_vs_approach_i_row_fraction.csv","reference_vs_approach_ii_counts.csv","reference_vs_approach_ii_row_fraction.csv","typing_summary.csv"]:
    f=TAB/name
    if f.exists():
        print("\n###",name); display(pd.read_csv(f,index_col=0))
# Out:
# ### approach_i_vs_ii_counts.csv
#                   Ambiguous  Endothelial  Epithelial  Fibroblast  Macrophage  \
# cell_type_scanpy
# Endothelial               7            0           0           1           0
# Epithelial               26            0          63           3           3
# Fibroblast               51            0           0          63           5
# Macrophage               59            0           0           8         128
# Plasma_cell              33            1           0          16          23
#
#                   Plasma_cell  Unassigned
# cell_type_scanpy
# Endothelial                 2          14
# Epithelial                  0          46
# Fibroblast                  2          16
# Macrophage                  5          42
# Plasma_cell               108         213
# ### approach_i_vs_ii_row_fraction.csv
#                   Ambiguous  Endothelial  Epithelial  Fibroblast  Macrophage  \
# cell_type_scanpy
# Endothelial        0.291667     0.000000    0.000000    0.041667    0.000000
# Epithelial         0.184397     0.000000    0.446809    0.021277    0.021277
# Fibroblast         0.372263     0.000000    0.000000    0.459854    0.036496
# Macrophage         0.243802     0.000000    0.000000    0.033058    0.528926
# Plasma_cell        0.083756     0.002538    0.000000    0.040609    0.058376
#
#                   Plasma_cell  Unassigned
# cell_type_scanpy
# Endothelial          0.083333    0.583333
# Epithelial           0.000000    0.326241
# Fibroblast           0.014599    0.116788
# Macrophage           0.020661    0.173554
# Plasma_cell          0.274112    0.540609
# ### typing_summary.csv
#                                                 value
# n_cells                                    938.000000
# approach_i_vs_ii_exact_agreement_fraction    0.385928
# approach_ii_unassigned_fraction              0.352878
# approach_ii_ambiguous_fraction               0.187633

# %% [markdown]
# ## SpatialData gene + segmentation + transcript overlays

# %%
# %run ../scripts/04f_spatial_overlap.py

# %% [markdown]
# ## Inspect SpatialData structure interactively

# %%
import spatialdata as sd
S=sd.read_zarr(PROJECT_ROOT/"data/spatial/GSM9046088_CosMx_FOV46.zarr")
print(S)
# Out:
# SpatialData object, with associated Zarr store: /research/rgs01/home/clusterHome/jqu/activities/learning/BioHackathon/BioHackathon-2026/Dataset_02_CosMx_revised/Dataset_02_CosMx_revised/data/spatial/GSM9046088_CosMx_FOV46.zarr
# ├── Points
# │     └── 'transcripts': DataFrame with shape: (<Delayed>, 9) (2D points)
# ├── Shapes
# │     └── 'cell_boundaries': GeoDataFrame shape: (1105, 1) (2D shapes)
# └── Tables
#       └── 'table': AnnData (1105, 1010)
# with coordinate systems:
#     ▸ 'global', with elements:
#         transcripts (Points), cell_boundaries (Shapes)
