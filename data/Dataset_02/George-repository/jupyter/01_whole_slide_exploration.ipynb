# %% [markdown]
# # 01 — Whole-slide exploration
#
# Run the tested whole-slide analysis, then inspect FOV structure and output tables interactively.

# %%
from pathlib import Path
import sys, os

# Notebook lives in PROJECT_ROOT/jupyter/.
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "jupyter" else Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT))
print("PROJECT_ROOT:", PROJECT_ROOT)
print("Python:", sys.executable)
assert (PROJECT_ROOT / "scripts").exists(), "Run this notebook from PROJECT_ROOT/jupyter or PROJECT_ROOT."
# Out:
# PROJECT_ROOT: /research/rgs01/home/clusterHome/jqu/activities/learning/BioHackathon/BioHackathon-2026/Dataset_02_CosMx_revised/Dataset_02_CosMx_revised
# Python: /home/jqu/.conda/envs/spatialdata/bin/python

# %%
# %run ../scripts/03_explore_whole_slide.py

# %%
import pandas as pd
from IPython.display import display
TAB=PROJECT_ROOT/"results/whole_slide/tables"
for f in sorted(TAB.glob("*.csv")):
    print("\n###", f.name)
    display(pd.read_csv(f).head(20))
# Out:
# ### cluster_by_FOV_fraction.csv
#     leiden         1         2         3         4         5         6  \
# 0        0  0.013468  0.018118  0.017316  0.004810  0.036716  0.029341
# 1        1  0.015522  0.013821  0.011695  0.004890  0.002552  0.001914
# 2        2  0.028523  0.027958  0.042643  0.035018  0.015250  0.014120
# 3        3  0.027069  0.033603  0.030492  0.027069  0.038892  0.039515
# 4        4  0.000773  0.000000  0.000000  0.000000  0.000386  0.000000
# 5        5  0.006603  0.023112  0.004953  0.005365  0.032604  0.026414
# 6        6  0.243076  0.220752  0.254237  0.203803  0.009095  0.047540
# 7        7  0.000000  0.000000  0.001241  0.000000  0.000000  0.000621
# 8        8  0.001437  0.000718  0.000000  0.000000  0.033046  0.018678
# 9        9  0.017304  0.021629  0.041817  0.033165  0.032444  0.013699
# 10      10  0.004695  0.005477  0.000000  0.000000  0.000000  0.000782
# 11      11  0.000000  0.000000  0.000000  0.000917  0.000000  0.000000
# ...
